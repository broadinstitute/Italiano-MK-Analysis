# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# bi = r'C:\Users\Prakrith\Desktop\test\skel\skeleton\170109_Inhibitors2_C5_3-0003_branchpoints.png'
# e = r'C:\Users\Prakrith\Desktop\test\skel\edges.csv'
# v = r'C:\Users\Prakrith\Desktop\test\skel\vertices.csv'

# %%
G = nx.cubical_graph()

# %%
plt.subplot(121)

# %%
nx.draw(G)

# %%
plt.subplot(122)

# %%
nx.draw(G, pos=nx.circular_layout(G), nodecolor='r', edge_color='b')
